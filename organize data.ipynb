# %%
import pandas as pd

# %% [markdown]
# # get user table and ratings table

# %%
movielens_ratings = pd.read_csv('dataset/movielens_ratings.csv')

# %%
movielens_ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
movielens_ratings[movielens_ratings['userId']==1]
# Out:
#      userId  movieId  rating  timestamp
# 0         1        1     4.0  964982703
# 1         1        3     4.0  964981247
# 2         1        6     4.0  964982224
# 3         1       47     5.0  964983815
# 4         1       50     5.0  964982931
# ..      ...      ...     ...        ...
# 227       1     3744     4.0  964980694
# 228       1     3793     5.0  964981855
# 229       1     3809     4.0  964981220
# 230       1     4006     4.0  964982903
# 231       1     5060     5.0  964984002
#
# [232 rows x 4 columns]

# %%
len(pd.unique(movielens_ratings['movieId']))
# Out:
# 9724

# %%
movielens_movies.shape
# Out:
# (9742, 3)

# %%
uids = pd.unique(movielens_ratings['userId'])

# %%
#total 610 users
l = len(uids)
l
# Out:
# 610

# %%
usernames = open("dataset/usernames", "r").read().split()

# %%
users_table = pd.DataFrame({'uid':uids, 'username':usernames[:l], 'password':['123']*l})

# %%
users_table.head()
# Out:
#    uid   username password
# 0    1  abomasnow      123
# 1    2       abra      123
# 2    3      absol      123
# 3    4   accelgor      123
# 4    5  aegislash      123

# %%
movielens_ratings.rename(columns={'userId':'uid'}, inplace=True)
ratings_table = movielens_ratings

# %%
ratings_table.head()
# Out:
#    uid  movieId  rating  timestamp
# 0    1        1     4.0  964982703
# 1    1        3     4.0  964981247
# 2    1        6     4.0  964982224
# 3    1       47     5.0  964983815
# 4    1       50     5.0  964982931

# %% [markdown]
# # combine movielens and imdb movies to create movie table

# %%
movielens_movies = pd.read_csv('dataset/movielens_movies.csv')

# %% [markdown]
# need to split the title in movie_lens to 'title' and 'year' column

# %%
import re

# %%
title_split = movielens_movies.title.str.split('\(|\)',expand=True,n=2)

# %%
movielens_movies.title =title_split[0].str.strip()

# %%
movielens_movies['year']=title_split[1]

# %%
movielens_movies.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %%
imdb_movies = pd.read_csv('dataset/IMDB_movies.csv')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
imdb_movies.head()
# Out:
#   imdb_title_id                        title  year                      genre  \
# 0     tt0000009                   Miss Jerry  1894                    Romance
# 1     tt0000574  The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2     tt0001892               Den sorte drøm  1911                      Drama
# 3     tt0002101                    Cleopatra  1912             Drama, History
# 4     tt0002130                    L'Inferno  1911  Adventure, Drama, Fantasy
#
#    duration                                        description
# 0        45  The adventures of a female reporter in the 1890s.
# 1        70  True story of notorious Australian outlaw Ned ...
# 2        53  Two men of high rank are both wooing the beaut...
# 3       100  The fabled queen of Egypt's affair with Roman ...
# 4        68  Loosely adapted from Dante's Divine Comedy and...

# %% [markdown]
# we only want certain columns

# %%
imdb_movies.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
imdb_movies = imdb_movies[['imdb_title_id','original_title','year','genre','duration','description']]

# %%
imdb_movies.rename(columns={'original_title':'title'}, inplace=True)

# %%
imdb_movies.head()
# Out:
#   imdb_title_id                        title  year                      genre  \
# 0     tt0000009                   Miss Jerry  1894                    Romance
# 1     tt0000574  The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2     tt0001892               Den sorte drøm  1911                      Drama
# 3     tt0002101                    Cleopatra  1912             Drama, History
# 4     tt0002130                    L'Inferno  1911  Adventure, Drama, Fantasy
#
#    duration                                        description
# 0        45  The adventures of a female reporter in the 1890s.
# 1        70  True story of notorious Australian outlaw Ned ...
# 2        53  Two men of high rank are both wooing the beaut...
# 3       100  The fabled queen of Egypt's affair with Roman ...
# 4        68  Loosely adapted from Dante's Divine Comedy and...

# %% [markdown]
# ## inner join movielens_movies and imdb_movies on title

# %%
movie_join = movielens_movies.merge(imdb_movies, on='title', how='inner')
movie_join.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres year_x imdb_title_id year_y  \
# 0  Adventure|Animation|Children|Comedy|Fantasy   1995     tt0114709   1995
# 1                   Adventure|Children|Fantasy   1995     tt0113497   1995
# 2                               Comedy|Romance   1995     tt0113228   1995
# 3                         Comedy|Drama|Romance   1995     tt0114885   1995
# 4                                       Comedy   1995     tt0113041   1995
#
#                           genre  duration  \
# 0  Animation, Adventure, Comedy        81
# 1     Adventure, Comedy, Family       104
# 2               Comedy, Romance       101
# 3        Comedy, Drama, Romance       124
# 4       Comedy, Family, Romance       106
#
#                                          description
# 0  A cowboy doll is profoundly threatened and jea...
# 1  When two kids find and play a magical board ga...
# 2  John and Max resolve to save their beloved bai...
# 3  Based on Terry McMillan's novel, this film fol...
# 4  George Banks must deal not only with the pregn...

# %%
movies_table = movie_join[['movieId','title','year_x','imdb_title_id','duration','description']]
movies_table.rename(columns={'movieId':'movielens_title_id','year_x':'year'}, inplace=True)
movies_table
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#       movielens_title_id                             title  year  \
# 0                      1                         Toy Story  1995
# 1                      2                           Jumanji  1995
# 2                      3                  Grumpier Old Men  1995
# 3                      4                 Waiting to Exhale  1995
# 4                      5       Father of the Bride Part II  1995
# ...                  ...                               ...   ...
# 7711              190207                              Tilt  2011
# 7712              190213                         John From  2015
# 7713              190219                             Bunny  1998
# 7714              191005                           Gintama  2017
# 7715              193573  Love Live! The School Idol Movie  2015
#
#      imdb_title_id  duration  \
# 0        tt0114709        81
# 1        tt0113497       104
# 2        tt0113228       101
# 3        tt0114885       124
# 4        tt0113041       106
# ...            ...       ...
# 7711     tt5435476        99
# 7712     tt3977428        95
# 7713     tt0432090       139
# 7714     tt5805470       131
# 7715     tt3837248        99
#
#                                             description
# 0     A cowboy doll is profoundly threatened and jea...
# 1     When two kids find and play a magical board ga...
# 2     John and Max resolve to save their beloved bai...
# 3     Based on Terry McMillan's novel, this film fol...
# 4     George Banks must deal not only with the pregn...
# ...                                                 ...
# 7711  An unemployed documentary filmmaker's behavior...
# 7712  Bored by spending the summer in the city, 15-y...
# 7713  Prior to his marriage, a young man asks for th...
# 7714  In an era where aliens have invaded and conque...
# 7715  The story of the film begins after the events ...
#
# [7716 rows x 6 columns]

# %% [markdown]
# ## calculate ratings from ratings_table

# %%
ratings_table.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
num_ratings = ratings_table.groupby(['movieId'], as_index=False).count()[['movieId','rating']]
num_ratings.rename(columns={'rating':'num_ratings'}, inplace=True)
num_ratings.head()
# Out:
#    movieId  num_ratings
# 0        1          215
# 1        2          110
# 2        3           52
# 3        4            7
# 4        5           49

# %%
ave_ratings = ratings_table.groupby(['movieId'], as_index=False).mean()[['movieId','rating']]
ave_ratings.rename(columns={'rating':'ave_rating'}, inplace=True)
ave_ratings.head()
# Out:
#    movieId  ave_rating
# 0        1    3.920930
# 1        2    3.431818
# 2        3    3.259615
# 3        4    2.357143
# 4        5    3.071429

# %%
movies_table.shape
# Out:
# (7716, 6)

# %%
# use only movie with ratings 
tmp=pd.merge(movies_table, num_ratings,how='inner', left_on='movielens_title_id',right_on='movieId')
tmp=pd.merge(tmp, ave_ratings,how='inner', left_on='movielens_title_id',right_on='movieId')
tmp.head()
# Out:
#    movielens_title_id                        title  year imdb_title_id  \
# 0                   1                    Toy Story  1995     tt0114709
# 1                   2                      Jumanji  1995     tt0113497
# 2                   3             Grumpier Old Men  1995     tt0113228
# 3                   4            Waiting to Exhale  1995     tt0114885
# 4                   5  Father of the Bride Part II  1995     tt0113041
#
#    duration                                        description  movieId_x  \
# 0        81  A cowboy doll is profoundly threatened and jea...          1
# 1       104  When two kids find and play a magical board ga...          2
# 2       101  John and Max resolve to save their beloved bai...          3
# 3       124  Based on Terry McMillan's novel, this film fol...          4
# 4       106  George Banks must deal not only with the pregn...          5
#
#    num_ratings  movieId_y  ave_rating
# 0          215          1    3.920930
# 1          110          2    3.431818
# 2           52          3    3.259615
# 3            7          4    2.357143
# 4           49          5    3.071429

# %%
movies_table = tmp

# %% [markdown]
# #  actors table

# %%
imdb_names = pd.read_csv('dataset/IMDB_names.csv')
imdb_names.head()
# Out:
#   imdb_name_id             name               birth_name  height  \
# 0    nm0000001     Fred Astaire  Frederic Austerlitz Jr.   177.0
# 1    nm0000002    Lauren Bacall        Betty Joan Perske   174.0
# 2    nm0000003  Brigitte Bardot          Brigitte Bardot   166.0
# 3    nm0000004     John Belushi        John Adam Belushi   170.0
# 4    nm0000005   Ingmar Bergman     Ernst Ingmar Bergman   179.0
#
#                                                  bio  \
# 0  Fred Astaire was born in Omaha, Nebraska, to J...
# 1  Lauren Bacall was born Betty Joan Perske on Se...
# 2  Brigitte Bardot was born on September 28, 1934...
# 3  John Belushi was born in Chicago, Illinois, US...
# 4  Ernst Ingmar Bergman was born July 14, 1918, t...
#
#                                        birth_details date_of_birth  \
# 0               May 10, 1899 in Omaha, Nebraska, USA    1899-05-10
# 1  September 16, 1924 in The Bronx, New York City...    1924-09-16
# 2                September 28, 1934 in Paris, France    1934-09-28
# 3         January 24, 1949 in Chicago, Illinois, USA    1949-01-24
# 4      July 14, 1918 in Uppsala, Uppsala län, Sweden    1918-07-14
#
#                             place_of_birth  \
# 0                     Omaha, Nebraska, USA
# 1  The Bronx, New York City, New York, USA
# 2                            Paris, France
# 3                   Chicago, Illinois, USA
# 4             Uppsala, Uppsala län, Sweden
#
#                                        death_details date_of_death  \
# 0  June 22, 1987 in Los Angeles, California, USA ...    1987-06-22
# 1  August 12, 2014 in New York City, New York, US...    2014-08-12
# 2                                                NaN           NaN
# 3  March 5, 1982 in Hollywood, Los Angeles, Calif...    1982-03-05
# 4  July 30, 2007 in Fårö, Gotlands län, Sweden  (...    2007-07-30
#
#                               place_of_death  \
# 0             Los Angeles, California, USA
# 1             New York City, New York, USA
# 2                                        NaN
# 3  Hollywood, Los Angeles, California, USA
# 4               Fårö, Gotlands län, Sweden
#
#                          reason_of_death  \
# 0                              pneumonia
# 1                                 stroke
# 2                                    NaN
# 3  acute cocaine and heroin intoxication
# 4                         natural causes
#
#                                       spouses_string  spouses  divorces  \
# 0  Robyn Smith  (27 June 1980 - 22 June 1987) (hi...        2         0
# 1  Jason Robards  (4 July 1961 - 10 September 196...        2         1
# 2  Bernard d'Ormale  (16 August 1992 - present)\n...        4         3
# 3  Judith Belushi-Pisano  (31 December 1976 - 5 M...        1         0
# 4  Ingrid Bergman  (11 November 1971 - 20 May 199...        5         4
#
#    spouses_with_children  children
# 0                      1         2
# 1                      2         3
# 2                      1         1
# 3                      0         0
# 4                      5         8

# %%
actors_table = imdb_names[['imdb_name_id','name','bio']]
actors_table.head()
# Out:
#   imdb_name_id             name  \
# 0    nm0000001     Fred Astaire
# 1    nm0000002    Lauren Bacall
# 2    nm0000003  Brigitte Bardot
# 3    nm0000004     John Belushi
# 4    nm0000005   Ingmar Bergman
#
#                                                  bio
# 0  Fred Astaire was born in Omaha, Nebraska, to J...
# 1  Lauren Bacall was born Betty Joan Perske on Se...
# 2  Brigitte Bardot was born on September 28, 1934...
# 3  John Belushi was born in Chicago, Illinois, US...
# 4  Ernst Ingmar Bergman was born July 14, 1918, t...

# %% [markdown]
# # casts table

# %%
imdb_casts = pd.read_csv('dataset/IMDb_title_principals.csv')
imdb_casts.head()
# Out:
#   imdb_title_id  ordering imdb_name_id  category  job  \
# 0     tt0000009         1    nm0063086   actress  NaN
# 1     tt0000009         2    nm0183823     actor  NaN
# 2     tt0000009         3    nm1309758     actor  NaN
# 3     tt0000009         4    nm0085156  director  NaN
# 4     tt0000574         1    nm0846887   actress  NaN
#
#                                           characters
# 0           ["Miss Geraldine Holbrook (Miss Jerry)"]
# 1                                   ["Mr. Hamilton"]
# 2  ["Chauncey Depew - the Director of the New Yor...
# 3                                                NaN
# 4                                     ["Kate Kelly"]

# %%
# only want movies that are in our movies table 
imdb_casts = imdb_casts[imdb_casts.imdb_title_id.isin(movies_table.imdb_title_id)] 
# select only actor and actress 
imdb_casts= imdb_casts[imdb_casts.category.isin(['actor','actress'])]

# %%
casts_table = imdb_casts[['imdb_title_id','imdb_name_id']]

# %%
casts_table.head()
# Out:
#     imdb_title_id imdb_name_id
# 81      tt0002461    nm0312600
# 82      tt0002461    nm0911963
# 83      tt0002461    nm0306817
# 84      tt0002461    nm0443857
# 233     tt0003772    nm0681933

# %% [markdown]
# # genre table

# %%
movie_join.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres year_x imdb_title_id year_y  \
# 0  Adventure|Animation|Children|Comedy|Fantasy   1995     tt0114709   1995
# 1                   Adventure|Children|Fantasy   1995     tt0113497   1995
# 2                               Comedy|Romance   1995     tt0113228   1995
# 3                         Comedy|Drama|Romance   1995     tt0114885   1995
# 4                                       Comedy   1995     tt0113041   1995
#
#                           genre  duration  \
# 0  Animation, Adventure, Comedy        81
# 1     Adventure, Comedy, Family       104
# 2               Comedy, Romance       101
# 3        Comedy, Drama, Romance       124
# 4       Comedy, Family, Romance       106
#
#                                          description
# 0  A cowboy doll is profoundly threatened and jea...
# 1  When two kids find and play a magical board ga...
# 2  John and Max resolve to save their beloved bai...
# 3  Based on Terry McMillan's novel, this film fol...
# 4  George Banks must deal not only with the pregn...

# %%
# use movielens's genres column 
genres = movie_join[['imdb_title_id','genres']][movie_join.imdb_title_id.isin(movies_table.imdb_title_id)]
genres.head()
# Out:
#   imdb_title_id                                       genres
# 0     tt0114709  Adventure|Animation|Children|Comedy|Fantasy
# 1     tt0113497                   Adventure|Children|Fantasy
# 2     tt0113228                               Comedy|Romance
# 3     tt0114885                         Comedy|Drama|Romance
# 4     tt0113041                                       Comedy

# %%
genres
# Out:
#      imdb_title_id                                       genres
# 0        tt0114709  Adventure|Animation|Children|Comedy|Fantasy
# 1        tt0113497                   Adventure|Children|Fantasy
# 2        tt0113228                               Comedy|Romance
# 3        tt0114885                         Comedy|Drama|Romance
# 4        tt0113041                                       Comedy
# ...            ...                                          ...
# 7711     tt5435476                                Drama|Romance
# 7712     tt3977428                                        Drama
# 7713     tt0432090                                    Animation
# 7714     tt5805470               Action|Adventure|Comedy|Sci-Fi
# 7715     tt3837248                                    Animation
#
# [7716 rows x 2 columns]

# %%
genres_table = genres[['imdb_title_id']].join(\
    genres.genres.str.split('|',expand=True)\
    .stack().reset_index(drop=True, level=1).rename('genres'))
genres_table.head()
# Out:
#   imdb_title_id     genres
# 0     tt0114709  Adventure
# 0     tt0114709  Animation
# 0     tt0114709   Children
# 0     tt0114709     Comedy
# 0     tt0114709    Fantasy

# %% [markdown]
# # summary
# for relational database:
# users_table
# ratings_table
# movies_table
# actors_table
#
# for noe4j:
# casts_table
# genres table

# %%
users_table.head()
# Out:
#    uid   username password
# 0    1  abomasnow      123
# 1    2       abra      123
# 2    3      absol      123
# 3    4   accelgor      123
# 4    5  aegislash      123

# %%
ratings_table.head()
# Out:
#    uid  movieId  rating  timestamp
# 0    1        1     4.0  964982703
# 1    1        3     4.0  964981247
# 2    1        6     4.0  964982224
# 3    1       47     5.0  964983815
# 4    1       50     5.0  964982931

# %%
movies_table.head()
# Out:
#    movielens_title_id                        title  year imdb_title_id  \
# 0                   1                    Toy Story  1995     tt0114709
# 1                   2                      Jumanji  1995     tt0113497
# 2                   3             Grumpier Old Men  1995     tt0113228
# 3                   4            Waiting to Exhale  1995     tt0114885
# 4                   5  Father of the Bride Part II  1995     tt0113041
#
#    duration                                        description
# 0        81  A cowboy doll is profoundly threatened and jea...
# 1       104  When two kids find and play a magical board ga...
# 2       101  John and Max resolve to save their beloved bai...
# 3       124  Based on Terry McMillan's novel, this film fol...
# 4       106  George Banks must deal not only with the pregn...

# %%
actors_table.head()
# Out:
#   imdb_name_id             name  \
# 0    nm0000001     Fred Astaire
# 1    nm0000002    Lauren Bacall
# 2    nm0000003  Brigitte Bardot
# 3    nm0000004     John Belushi
# 4    nm0000005   Ingmar Bergman
#
#                                                  bio
# 0  Fred Astaire was born in Omaha, Nebraska, to J...
# 1  Lauren Bacall was born Betty Joan Perske on Se...
# 2  Brigitte Bardot was born on September 28, 1934...
# 3  John Belushi was born in Chicago, Illinois, US...
# 4  Ernst Ingmar Bergman was born July 14, 1918, t...

# %%
casts_table.head()
# Out:
#     imdb_title_id imdb_name_id
# 81      tt0002461    nm0312600
# 82      tt0002461    nm0911963
# 83      tt0002461    nm0306817
# 84      tt0002461    nm0443857
# 233     tt0003772    nm0681933

# %%
genres_table.head()
# Out:
#   imdb_title_id     genres
# 0     tt0114709  Adventure
# 0     tt0114709  Animation
# 0     tt0114709   Children
# 0     tt0114709     Comedy
# 0     tt0114709    Fantasy

# %% [markdown]
# # save to local

# %%
path = 'dataset/processed/'
users_table.to_csv(path + 'users_table', index=False)
ratings_table.to_csv(path + 'ratings_table', index=False)
movies_table.to_csv(path + 'movies_table', index=False)
actors_table.to_csv(path + 'actors_table', index=False)
casts_table.to_csv(path + 'casts_table', index=False)
genres_table.to_csv(path + 'genres_table', index=False)
